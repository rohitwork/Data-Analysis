# %% [markdown]
# ## Manchester United Wins and Loss Under Different Managers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn
import warnings
warnings.filterwarnings("ignore")
print("Imported")
# Out:
# Imported

# %%
data=pd.read_csv("stats.csv")

# %%
data.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
# ...

# %%
data_utd=data[data.team=="Manchester United"]

# %% [markdown]
# ## Data Wrangling

# %%
data_utd
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 20   Manchester United  27.0     5.0   80.0            51.0             2.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 61   Manchester United  27.0     7.0   86.0            49.0             4.0
# 80   Manchester United  23.0     4.0   78.0            56.0             3.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
# 146  Manchester United  19.0    12.0   64.0            66.0             3.0
# 163  Manchester United  20.0     8.0   62.0            64.0             5.0
# 183  Manchester United  19.0    10.0   49.0            65.0             1.0
# 205  Manchester United  18.0     5.0   54.0            78.0             2.0
# ...

# %%
data_utd.columns
# Out:
# Index(['team', 'wins', 'losses', 'goals', 'total_yel_card', 'total_red_card',
#        'total_scoring_att', 'ontarget_scoring_att', 'hit_woodwork',
#        'att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
#        'att_obox_goal', 'goal_fastbreak', 'total_offside', 'clean_sheet',
#        'goals_conceded', 'saves', 'outfielder_block', 'interception',
#        'total_tackle', 'last_man_tackle', 'total_clearance', 'head_clearance',
#        'own_goals', 'penalty_conceded', 'pen_goals_conceded', 'total_pass',
#        'total_through_ball', 'total_long_balls', 'backward_pass',
#        'total_cross', 'corner_taken', 'touches', 'big_chance_missed',
#        'clearance_off_line', 'dispossessed', 'penalty_save',
#        'total_high_claim', 'punches', 'season'],
#       dtype='object')

# %%
data_utd.drop(data_utd.columns.difference(['team','wins','losses','season']), 1, inplace=True)

# %%
data_utd
# Out:
#                   team  wins  losses     season
# 0    Manchester United  28.0     5.0  2006-2007
# 20   Manchester United  27.0     5.0  2007-2008
# 40   Manchester United  28.0     4.0  2008-2009
# 61   Manchester United  27.0     7.0  2009-2010
# 80   Manchester United  23.0     4.0  2010-2011
# 101  Manchester United  28.0     5.0  2011-2012
# 120  Manchester United  28.0     5.0  2012-2013
# 146  Manchester United  19.0    12.0  2013-2014
# 163  Manchester United  20.0     8.0  2014-2015
# 183  Manchester United  19.0    10.0  2015-2016
# 205  Manchester United  18.0     5.0  2016-2017
# 221  Manchester United  25.0     7.0  2017-2018

# %%
data_utd.shape
# Out:
# (12, 4)

# %%
data_utd1=[pd.Series(['Manchester United',19.0,10.0,"2018-2019"],index=data_utd.columns),
pd.Series(['Manchester United',18.0,8.0,"2019-2020"],index=data_utd.columns),
pd.Series(['Manchester United',25.0,4.0,"2020-2021"],index=data_utd.columns)]

# %%
data_utd2=data_utd.append(data_utd1,ignore_index=True)

# %%
data_utd2
# Out:
#                  team  wins  losses     season
# 0   Manchester United  28.0     5.0  2006-2007
# 1   Manchester United  27.0     5.0  2007-2008
# 2   Manchester United  28.0     4.0  2008-2009
# 3   Manchester United  27.0     7.0  2009-2010
# 4   Manchester United  23.0     4.0  2010-2011
# 5   Manchester United  28.0     5.0  2011-2012
# 6   Manchester United  28.0     5.0  2012-2013
# 7   Manchester United  19.0    12.0  2013-2014
# 8   Manchester United  20.0     8.0  2014-2015
# 9   Manchester United  19.0    10.0  2015-2016
# 10  Manchester United  18.0     5.0  2016-2017
# 11  Manchester United  25.0     7.0  2017-2018
# 12  Manchester United  19.0    10.0  2018-2019
# 13  Manchester United  18.0     8.0  2019-2020
# 14  Manchester United  25.0     4.0  2020-2021

# %% [markdown]
# ## Wins Per Season

# %%
utd_wins=["wins","season"]
utd_winsSeason=data_utd2[utd_wins]

# %%
utd_winsSeason
# Out:
#     wins     season
# 0   28.0  2006-2007
# 1   27.0  2007-2008
# 2   28.0  2008-2009
# 3   27.0  2009-2010
# 4   23.0  2010-2011
# 5   28.0  2011-2012
# 6   28.0  2012-2013
# 7   19.0  2013-2014
# 8   20.0  2014-2015
# 9   19.0  2015-2016
# 10  18.0  2016-2017
# 11  25.0  2017-2018
# 12  19.0  2018-2019
# 13  18.0  2019-2020
# 14  25.0  2020-2021

# %% [markdown]
# ## Loss Per Season

# %%
utd_loss=['losses','season']
utd_lossSeason=data_utd2[utd_loss]

# %%
utd_lossSeason
# Out:
#     losses     season
# 0      5.0  2006-2007
# 1      5.0  2007-2008
# 2      4.0  2008-2009
# 3      7.0  2009-2010
# 4      4.0  2010-2011
# 5      5.0  2011-2012
# 6      5.0  2012-2013
# 7     12.0  2013-2014
# 8      8.0  2014-2015
# 9     10.0  2015-2016
# 10     5.0  2016-2017
# 11     7.0  2017-2018
# 12    10.0  2018-2019
# 13     8.0  2019-2020
# 14     4.0  2020-2021

# %% [markdown]
# ## Plotting Wins And Loss Under Different managers

# %%
plt.figure(figsize=(25,15))
plt.title("Wins and Losses Per season")
#Wins per Season
plt.plot(utd_winsSeason.season,utd_winsSeason.wins,label="wins",marker='o')
#Loss per season
plt.plot(utd_lossSeason.season,utd_lossSeason.losses,label="Loss",marker='o')
plt.grid(which="major",axis="both",linestyle='-.',linewidth=0.75)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.ylim(0,30)

try:
    plt.annotate("Moyes Comes in",xy=("2013-2014",19),xytext=("2013-2014",21),arrowprops=dict(facecolor="Black",shrink=0.05,width=1,headwidth=8),fontsize=16)
    
    plt.annotate("Moyes Comes in",xy=("2013-2014",12),xytext=("2013-2014",14),arrowprops=dict(facecolor="Black",shrink=0.05,width=1,headwidth=8),fontsize=16)
    
    plt.annotate('Van Gaal comes in', xy=('2014-2015',20), xytext=('2014-2015', 23),arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=8), fontsize =16) 
    
    plt.annotate('Van Gaal comes in', xy=('2014-2015',8), xytext=('2014-2015', 11),arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=8), fontsize =16)
    
    plt.annotate('Mourinho comes in', xy=('2016-2017',18), xytext=('2016-2017', 20),arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=8), fontsize =16) 
    
    plt.annotate('Mourinho comes in', xy=('2016-2017',5), xytext=('2016-2017', 8),arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=8), fontsize =16) 
    
    plt.annotate('Ole Comes in',xy=("2018-2019",19), xytext=('2017-2018',22),arrowprops=dict(facecolor="black",shrink=0.05,width=1,headwidth=8),fontsize=16)
                
    plt.annotate('Ole Comes in',xy=("2018-2019",10), xytext=('2017-2018',12),arrowprops=dict(facecolor="black",shrink=0.05,width=1,headwidth=8),fontsize=16)
    
    plt.text("2009-2010",16,"The Sir Alex Ferguson Era",horizontalalignment='center',verticalalignment='center',fontsize=25,bbox=dict(facecolor="red",alpha=0.5))
except TypeError:
    pass
